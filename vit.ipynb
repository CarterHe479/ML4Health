# %%
from data_loader import Nutrition5KDatasetWithSides
from torchvision import transforms

# Define basic transforms if needed
rgb_transform = transforms.Compose([
    transforms.ToTensor(),
])

depth_transform = transforms.Compose([
    transforms.ToTensor(),
])

# Initialize dataset
dataset = Nutrition5KDatasetWithSides(
    root_dir="~/Documents/nutrition5k_dataset",  # adjust if needed
    split="train",
    rgb_transform=rgb_transform,
    depth_transform=depth_transform
)

# Load one sample
sample = dataset[0]

print("RGB shape:", sample["rgb"].shape)           # [3, 480, 640]
print("Depth shape:", sample["depth"].shape)       # [1, 480, 640]
print("Side images shape:", sample["side_images"].shape)  # [4, 3, 480, 640]
print("Dish ID:", sample["dish_id"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 22
#      14 dataset = Nutrition5KDatasetWithSides(
#      15     root_dir="~/Documents/nutrition5k_dataset",  # adjust if needed
#      16     split="train",
#      17     rgb_transform=rgb_transform,
#      18     depth_transform=depth_transform
#      19 )
#      21 # Load one sample
# ---> 22 sample = dataset[0]
#      24 print("RGB shape:", sample["rgb"].shape)           # [3, 480, 640]
#      25 print("Depth shape:", sample["depth"].shape)       # [1, 480, 640]
#
# File ~/Documents/NutritionEstimation/data_loader.py:150, in Nutrition5KDatasetWithSides.__getitem__(self, idx)
#     149 def __getitem__(self, idx):
# --> 150     sample = self.samples[idx]
#     151     rgb_path = sample["rgb"]
#     152     depth_path = sample["depth"]
#
# IndexError: list index out of range

# %%
# Out:
# 0
